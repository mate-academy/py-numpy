# %% [markdown]
# # Numpy

# %% [markdown]
# ## Task 1
#
# You should import the necessary libraries. You will use `numpy` and `sys` libraries.
#
#
# > Don't forget to import `numpy` in the short form.

# %%
import numpy as np
import sys

# %% [markdown]
# ## Task 2
#
# Create arrays with using Python default syntax and using `numpy`. Also, print the size of the arrays in bytes. You should use `sys` library for this task.
#
# Requirements for arrays:
# * length of the array should be `1000`;
# * array should contain zeros;
# * the second array should be generated by `numpy` library, and should have as little memory as possible.

# %%
python_array = [0] * 1000
sys.getsizeof(python_array)
# Out:
# 8056

# %%
numpy_array = np.zeros(1000, dtype=np.int8)
sys.getsizeof(numpy_array)
# Out:
# 1112

# %% [markdown]
# ## Task 3
#
# Write manually a small float array using `numpy` syntax number should be in the range from `0` to `10.0`. Also, you should get the first, the third, and the last elements of the array using multi-indexing.
#
# Requirements:
# * length of the array should be from `5` to `10`.

# %%
float_array = np.arange(0, 11, dtype=float)
float_array[[0, 2, -1]]
# Out:
# array([ 0.,  2., 10.])

# %% [markdown]
# ## Task 4
#
# You have the array `array = np.array([2.3, 7.8, 3.2, 1.1, 5.8, 9.5, 17.6, 11.1])` using multi-indexing you should summarize a subsequence of an array and get the `27` as the result.

# %%
array = np.array([2.3, 7.8, 3.2, 1.1, 5.8, 9.5, 17.6, 11.1])
array[[1, 7, 4, 0]].sum()
# Out:
# 27.0

# %% [markdown]
# ## Task 5
#
# You have a matrix `A`:
#
# ```python
# A = np.array([
#     [1, 6],
#     [2, 8],
#     [3, 11],
#     [3, 10],
#     [1, 7]
# ])
# ```
#
# Follow the comments in the next cells and write the code.

# %%
A = np.array([
    [1, 6],
    [2, 8],
    [3, 11],
    [3, 10],
    [1, 7]
])

# %% [markdown]
# ### Task 5.1 Find the mean for each column by `x` axis

# %%
np.mean(A, axis=1)
# Out:
# array([3.5, 5. , 7. , 6.5, 4. ])

# %% [markdown]
# ### Task 5.2 Get the standard deviation by `y` axis

# %%
np.std(A, axis=0)
# Out:
# array([0.89442719, 1.8547237 ])

# %% [markdown]
# ### Task 5.3 Get the sum of all elements in `A` by `y` axis

# %%
np.sum(A, axis=0)
# Out:
# array([10, 42])

# %% [markdown]
# ### Task 5.4 Get the following result using multi-dim selection:
#
# ```python
# [
#     [1, 6],
#     [2, 8],
#  ]
# ```

# %%
A[:2]
# Out:
# array([[1, 6],
#        [2, 8]])

# %% [markdown]
# ##  Task 5.5. Get the following result using multi-dim selection:
# ```python
# [
#     [1, 6],
#     [3, 11],
#     [1, 7]
#  ]
# ```

# %%
A[[0, 2, 4]]
# Out:
# array([[ 1,  6],
#        [ 3, 11],
#        [ 1,  7]])

# %% [markdown]
# ## Task 6
#
# Rewrite Python code to `numpy` code. Also, estimate the time of execution for both implementations.
#
# > Please, note: `unknown_signature` this name just hide the real name of the function, to make the task more complicated.

# %% [markdown]
# ### Task 6.1

# %%
# Python code
# %timeit [i for i in range(1000000)]
# Out:
# 49.6 ms ± 1.97 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit np.arange(1000000, dtype=np.int8)
# Out:
# 753 µs ± 2.56 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ### Task 6.2

# %%
# Python code
def unknown_signature(vector1, vector2):
    result = 0
    for i in range(len(vector1)):
        result += vector1[i] * vector2[i]
    return result

vector1 = [1, 2, 3]
vector2 = [4, 5, 6]
result = 0

# %timeit unknown_signature(vector1, vector2)
result
# Out:
# 432 ns ± 172 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 0

# %%
def unknown_signature_np(vector1, vector2):
    result = np.dot(vector1, vector2)
    return result

vector1 = np.array([1, 2, 3])
vector2 = np.array([4, 5, 6])

# %timeit unknown_signature_np(vector1, vector2)
result
# Out:
# 1.29 µs ± 23.2 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 0

# %% [markdown]
# ### Task 6.3

# %%
# Python code
def unknown_signature(matrix1, matrix2):
    result = []
    for i in range(len(matrix1)):
        row = []
        for j in range(len(matrix1[i])):
            row.append(matrix1[i][j] * matrix2[i][j])
        result.append(row)
    return result

matrix1 = [[1, 2], [3, 4]]
matrix2 = [[5, 6], [7, 8]]

# %timeit unknown_signature(matrix1, matrix2)
result
# Out:
# 910 ns ± 11 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 0

# %%
def unknown_signature_np(matrix1, matrix2):
    result = np.multiply(matrix1, matrix2)
    return result.tolist()

matrix1 = np.array([[1, 2], [3, 4]])
matrix2 = np.array([[5, 6], [7, 8]])

# %timeit unknown_signature_np(matrix1, matrix2)
result
# Out:
# 884 ns ± 40.6 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 0

# %% [markdown]
# ### Task 6.4

# %%
# Python code
def unknown_signature(lst):
    total = 0
    for num in lst:
        total += num
    result = total / len(lst)
    return result

lst = [1, 2, 3, 4, 5]

# %timeit unknown_signature(lst)
result
# Out:
# 393 ns ± 155 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# 0

# %%
def unknown_signature_np(lst):
    result = np.mean(lst)
    return result

lst = np.array([1, 2, 3, 4, 5])

# %timeit unknown_signature_np(lst)
result
# Out:
# 9.07 µs ± 1.63 µs per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 0

# %% [markdown]
# ## Task 7
#
# Rewrite Python code to `numpy` code (Masks).

# %% [markdown]
# ### Task 7.1

# %%
# Python code
def unknown_signature(lst, mask, new_value):
    for i in range(len(lst)):
        if mask[i]:
            lst[i] = new_value

lst = [1, 2, 3, 4, 5]
mask = [True, False, True, False, True]
new_value = 0

# %timeit unknown_signature(lst, mask, new_value)
lst
# Out:
# 367 ns ± 12.4 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# [0, 2, 0, 4, 0]

# %%
def unknown_signature_np(lst, mask, new_value):
    lst = np.array(lst)
    lst[mask] = new_value
    return lst.tolist()

lst = [1, 2, 3, 4, 5]
mask = [True, False, True, False, True]
new_value = 0

# %timeit unknown_signature(lst, mask, new_value)
lst
# Out:
# 357 ns ± 9.71 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
# [0, 2, 0, 4, 0]

# %% [markdown]
# ### Task 7.2

# %%
# Python code
def unknown_signature(lst1, lst2):
    bitwise_complement = [~x for x in lst1]
    bitwise_and = [x & y for x, y in zip(lst1, lst2)]
    bitwise_or = [x | y for x, y in zip(lst1, lst2)]
    return bitwise_complement, bitwise_and, bitwise_or

list1 = [5, 2, 7, 4, 9]
list2 = [3, 6, 1, 8, 10]

result_bitwise_complement, result_bitwise_and, result_bitwise_or = unknown_signature(list1, list2)
# %timeit result_bitwise_complement, result_bitwise_and, result_bitwise_or
# Out:
# 45.4 ns ± 1.69 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
def unknown_signature_np(lst1, lst2):   
    bitwise_complement = np.bitwise_not(lst1)
    bitwise_and = np.bitwise_and(lst1, lst2)
    bitwise_or = np.bitwise_or(lst1, lst2)
    return bitwise_complement, bitwise_and, bitwise_or

list1 = np.array([5, 2, 7, 4, 9])
list2 = np.array([3, 6, 1, 8, 10])

result_bitwise_complement, result_bitwise_and, result_bitwise_or = unknown_signature(list1, list2)
# %timeit result_bitwise_complement, result_bitwise_and, result_bitwise_or
# Out:
# 43.8 ns ± 0.541 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# ### Task 7.3 Optional

# %%
# Python code
def unknown_signature(lst):
    result = []
    for num in lst:
        if num % 2 == 0 and (num % 3 == 0 or num > 10):
            modified_num = (num ^ 7) + 2
            result.append(modified_num)
    return result

my_list = [6, 9, 12, 14, 17, 20]
result_python_style = unknown_signature(my_list)
# %timeit result_python_style
# Out:
# 16.5 ns ± 0.227 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
def unknown_signature_np(lst):
    lst = np.array(lst)
    mask = np.logical_and(lst % 2 == 0, np.logical_or(lst % 3 == 0, lst > 10))
    modified_nums = (np.bitwise_xor(lst[mask], 7) + 2).tolist()
    return modified_nums

my_list = [6, 9, 12, 14, 17, 20]
result_numpy_style = unknown_signature_np(my_list)
# %timeit result_numpy_style
# Out:
# 16.7 ns ± 0.215 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)
